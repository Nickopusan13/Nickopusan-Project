# %%
import pandas as pd
import re

# %%
df = pd.read_csv(r"C:\Freelance\Document\Airbnb.csv", dtype=str, keep_default_na=False)

# %%
df
# Out:
#       No baths bedrooms beds guest   hosted_by  \
# 0      1     3        3    6    12       Rafif
# 1      2     3        4    7    12       Rafif
# 2      3     1        2    4     5  Ryan Hilmi
# 3      4     3        3    3     9       Rafif
# 4      5   3.5        3    5    10       Rafif
# ..   ...   ...      ...  ...   ...         ...
# 241  242   2.5        3    8    12     Michael
# 242  243     1        2    4     7      Ramona
# 243  244     1        1    2     3  Saras Tira
# 244  245   3.5        3    3    12        Noel
# 245  246   4.5        2    2    10      Wangie
#
#                                                   name    price  \
# 0                               RustWood Villa W/ Pool   950000
# 1                        Villa Alinda C02 by Kava Stay   800000
# 2    kitanari-haeun Room: Apart Gateway Pasteur Ban...   470400
# 3                            Sentra Villa by Kava Stay   750000
# 4                        Casa De Arumanis by Kava Stay   900000
# ...

# %%
df.replace("", "NULL", inplace=True)

# %%
df.to_csv("cleaned_data.csv", index=False)

# %%
df.isna().sum()
# Out:
# No                0
# baths             0
# bedrooms          0
# beds              0
# guest             0
# hosted_by         0
# name              0
# price             0
# price_discount    0
# reviews           0
# stars             0
# title             0
# url               0
# dtype: int64
